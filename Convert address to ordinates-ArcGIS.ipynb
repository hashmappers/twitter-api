# %%
import tweepy
import dataset
from textblob import TextBlob
from sqlalchemy.exc import ProgrammingError
import json
import requests
import numpy as np

# %%
API_KEY = "AIzaSyBKZAk7K3vkTZ3EWbxANXU-vFJz6t6TC8o"

# %%
TRACK_TERMS = ["#"]
TWITTER_APP_KEY = 'uElRfzQJS8wRsXGKOh2olgDjz'
TWITTER_APP_SECRET = 'tOfDipFDeUYebPWS8QRBa8jKgrCVpjTMzPGq66emQO2dkoPA6Z'

TWITTER_KEY = '1014246746384265217-LOwVfHmmiA8RiyBxJq4J9KfS7fOc2l'

TWITTER_SECRET = 'duWDvZWvFkCcsBYJZBwrDoMZhdcKpw3gnd40DywRZe9BY'

CONNECTION_STRING = "sqlite:///tweets.db"

TABLE_NAME = "election"
CSV_NAME = "test_7.csv"

# %%
import urllib


def transfer_address(address):
    address = urllib.parse.quote_plus(address)
    #print(address)
    geocode_url = "http://geocode.arcgis.com/arcgis/rest/services/World/GeocodeServer/geocodeAddresses?addresses=%7B'records':%5B%7B'attributes':%7B'OBJECTID':1,'SingleLine':'{}'%7D%7D%5D%7D&token=isX1plRNHsoX1pjJfSav1-rt0VpBA6zMjYhvzyVmrkaViQX-B6t4LzQaZ62BXNDmDy4EmNAbprMetvekmtfEO9MbhtFXzdiCIh9ru6tp8QCsXHF-UbSiBfWFUv-epP01tCxprBzDIXW5MEFXyNo6Xw..&f=pjson".format(address)
    #print(geocode_url)
    f = urllib.request.urlopen(geocode_url)
    results = f.read()
    results = json.loads( results)
    print (results)
    
    if 'locations' not in results:
        output = {           
            "latitude": None,
            "longitude": None,
        }
    elif len(results['locations'][0]['address']) == 0:
        output = {           
            "latitude": None,
            "longitude": None,
        }           
    else:    
        answer = results['locations'][0]
        output = {            
            "latitude": answer.get('location').get('x'),
            "longitude": answer.get('location').get('y'),
        }
    return output

# %%
o = transfer_address('Aqui y Alla')
print(o)
# Out:
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'locations': [{'address': 'de Aquí y de Allá', 'location': {'x': -64.18025992299994, 'y': -31.418379948999984}, 'score': 96.82, 'attributes': {'ResultID': 1, 'Loc_name': 'World', 'Status': 'M', 'Score': 96.82, 'Match_addr': 'de Aquí y de Allá', 'LongLabel': 'de Aquí y de Allá, San Jerónimo 319, Córdoba, X5000, Córdoba, ARG', 'ShortLabel': 'de Aquí y de Allá', 'Addr_type': 'POI', 'Type': 'Home Improvement Store', 'PlaceName': 'de Aquí y de Allá', 'Place_addr': 'San Jerónimo 319, Córdoba, X5000, Córdoba', 'Phone': '', 'URL': '', 'Rank': 19, 'AddBldg': '', 'AddNum': '319', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': 'R', 'StPreDir': '', 'StPreType': '', 'StName': 'San Jerónimo', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': 'San Jerónimo 319', 'Block': '', 'Sector': '', 'Nbrhd': 'Córdoba', 'District': '', 'City': '
# ...

# %%
import json

# %%
with open("C:/Users/jinx9636/Downloads/tweets_geo_extent_4.json", 'r') as f:
    datastore = json.load(f)
    
output_dict = {'data':[]}
#Use the new datastore datastructure
for i in range(len(datastore["data"])):
    print(datastore["data"][i]["primary_geo"])
    output = transfer_address(datastore["data"][i]["primary_geo"] )
    print(output)
    output_dict['data'].append(output)
    
print(output_dict)
# Out:
# USA
# ...

# %%
with open('output_ordinates_4.json', 'w') as f:
        json.dump(output_dict, f)
